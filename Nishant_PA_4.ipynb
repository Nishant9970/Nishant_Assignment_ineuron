# %% [markdown]
# # Programming Assignment

# %% [markdown]
# # Nishant Rai

# %%
# 1. Write a Python Program to Find the Factorial of a Number?

fact = 1
num = int(input("Enter the number: "))

for i in range(1,num+1):
    fact = fact*i
    
print(fact)
# Out:
# Enter the number: 5
# 120

# %%
# 2. Write a Python Program to Display the multiplication Table?

num = int(input("Enter the number: "))

for i in range(1,10+1):
    print(num,'*',i,' = ',num*i)
# Out:
# Enter the number: 2
# 2 * 1  =  2
# 2 * 2  =  4
# 2 * 3  =  6
# 2 * 4  =  8
# 2 * 5  =  10
# 2 * 6  =  12
# 2 * 7  =  14
# 2 * 8  =  16
# 2 * 9  =  18
# 2 * 10  =  20

# %%
# 3. Write a Python Program to Print the Fibonacci sequence?

# here n is number of elements in Fibonacci sequence i.e. it starts from 1
n = int(input("Enter the number: "))
a = 0
b = 1

for i in range(0,n):
    print(a)
    a,b = b,b+a
# Out:
# Enter the number: 5
# 0
# 1
# 1
# 2
# 3

# %%
#4. Write a Python Program to Check Armstrong Number?

n = int(input("Enter the number: "))
sum_var = 0
temp = n

while(temp):
    rem = temp%10
    temp = temp//10
    sum_var += rem**3
    
if(sum_var == n):
    print("It is an Armstrong number")
else:
    print("It is not a Armstrong number")
# Out:
# Enter the number: 407
# It is an Armstrong number

# %%
# 5. Write a Python Program to Find Armstrong Number in an Interval?


def Armstrong(n):
    sum_var = 0
    temp = n
    while(temp):
        rem = temp%10
        temp = temp//10
        sum_var += rem**3

    if(sum_var == n):
        return True
    else:
        return False
    
lower_bound = int(input("Enter the Lower bound: "))
upper_bound = int(input("Enter the Upper bound: "))

for i in range(lower_bound, upper_bound+1):
    if(Armstrong(i)):
        print(i)
# Out:
# Enter the Lower bound: 1
# Enter the Upper bound: 1000
# 1
# 153
# 370
# 371
# 407

# %%
# 6. Write a Python Program to Find the Sum of Natural Numbers?

n = int(input("Enter the number of First 'n' Natural numbers you want to add: "))

print(int((n*(n+1))/2))
# Out:
# Enter the number of First 'n' Natural numbers you want to add: 10
# 55

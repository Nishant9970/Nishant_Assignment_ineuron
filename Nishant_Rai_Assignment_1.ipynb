# %% [markdown]
# #  Assignment 1

# %% [markdown]
# Name: Nishant Bipin Rai

# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %% [raw]
# Answer: -
#
# Values: 'hello', -87.8, 6
#
# Expressions: *, -, /, +

# %% [markdown]
# 2. What is the difference between string and variable?

# %% [raw]
# Answer: -
#
# String:
# 1. String is a built-in data type.
# 2. String is collection of characters
# 3. A variable can be of type string.
# 4. Example "Nishant" this is a string.
#
# Variable:
# 1. A varibale is a container to used to store data (in main memory).
# 2. A Variable can store data or values that may be of type int, float or    string.
# 3. Example Name = "Nishant" here Name is a variable of type string that    stores "Nishant".

# %% [markdown]
# 3. Describe three different data types.

# %% [raw]
# Answer: -
#
# 1. int: int stands for integer in python.
#         It is a built-in data type in python that is used to store
#         integer values.
#         Exampe: 23, 625 etc.
#
# 2. float: float stands for floating point representation in python.
#           It is a built-in data type in python that is used to store
#           numbers with a decimal point or precision.
#           Example: 23.33, 658.925 etc.
#
# 3. str: str stands for strings in python.
#         It is a built-in data type in python that is used to store
#         combination of characters, these characters may be  Alphabets,
#         numbers , or special characters.
#         string is specified using a double quote or single quote.
#         Example: "@123", 'Nishant', "9970"

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [raw]
# Answer:
# 1. An expression is a statement that is made up of one or more operators
#    and operands.
# 2. Every expression always evaluates to a value that may be of type
#    boolean, integer, float etc.
# 3. Example a = 3 + 6
#           is an expression.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [raw]
# Answer:
#
# Statement:
#        1. A statement is the basic building block of a program. A
#           program may contain multiple statements.
#        2. A statement is an instruction that is specified in a single
#           line.
#        3. Example: import pandas
#           this is an import statement.
#
# expression:
#       1. An expression is a statement that evaluates to a value.
#       2. An expression adds logic to a statement using Arithmetic,
#       logical operators etc.
#       3. every expression is a statement but every statement may or may
#       not be an expression.
#       4. Example: a = 2 + 3   is an expression.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [raw]
# Answer:
#
# After running the above code variable bacon will contain the value 22.
#
# The reason for this behaviour is that the expression, bacon + 1 will not change the value inside the variable bacon, since the result is not being stored in the same variable.

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [raw]
# Answer:
#
#  'spam' + 'spamspam' will evaluate to 'spamspamspam'.
#
#  'spam'*3  will evaluate to 'spamspamspam'.

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [raw]
# Answer:
#     eggs is a valid variable name because it starts with an alphabet.
#
#     100 is an invalid variable name because it starts with a number
#     which is not allowed in python.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [raw]
# Answer:
#     int(), float(), str() can be used to get the integer, floating-point number, or string version of a value respectively.

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [raw]
# Answer:
#     'I have eaten ' + 99 + ' burritos.'
#
#     the above expression will cause error because here we are trying to concatenate a string with an integer which is inavlid.
#
#     we can use '99' instead of 99, then it will not cause an error because '99' is also a string so it will get concatenated.
#
#     'I have eaten ' + '99' + ' burritos.'

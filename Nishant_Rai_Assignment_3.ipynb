# %% [markdown]
# # Assignment 3

# %% [markdown]
# Nishant Rai

# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# Answer: -
#
# Having functions in our program is advantageous because it helps us to reuse the code that we have written to perform a specific task.
# functions helps us to apply the principle of DRY (Do not Repeat Yourself )

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Answer: -
#
# The code in a function runs when the function is called.

# %% [markdown]
# 3. What statement creates a function?
#
# Answer: -
#
# the statement def func(args) helps us to create a function
#
# example:-
#
# def func(args):
#     pass

# %% [markdown]
# 4. What is the difference between a function and a function call?
#
# Answer:-
#
# A function can be defined as a set of code that performs a specific task and that can be reused.
#
# whereas the function call is a statement that is used to call a function already defined in our program or imported from other modules, for execution.

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Answer: -
#
# There is only one global scope in a python program
#
# Theoretically there can be infinite number of local scopes in a python program depending on the nature of the code

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?
#
# Answer: -
#
# When a function call returns, variables in local scope are destroyed or erased from the memory(stack).

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Answer: -
#
# return value is a value that is returned by a function after the successful execution of code or instructions inside the functions.
# it can be of type None, int, float,str etc
#
# Yes, it is possible to have a return value (returned by another function) in an expression,
#
# Example:
#
# a = add(5,2)*2

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Answer: -
#
# If a function does not have a return statement then in such case the return value will be None.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?
#
# Answer: -
# using the global keyword we can make a function variable refer to global variable.

# %% [markdown]
# 10. What is the data type of None?
#
# Answer: -
#
# data type of none is NoneType

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Answer: -
#
# first it wil check for the given module in the current working directory.
# then it will check for the given module in built-in python modules or installed packages.
#
# if the given module exists then it will be imported.
#
# Thereafter python will execute the module.

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Answer:-
#
# spam.bacon()

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Answer:-
# We can use exceptional handling to prevent our program from crashing if it encounters an errors.

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Answer:-
#
# we use try clause to test set of codes when there is a chance of them throwing an exception (at runtime).
#
#
# we use the except clause to catch the exception thrown by the lines of code in the try block and handle the exception so that our program doesn't crashes.

# %% [markdown]
# # Assingment 6

# %% [markdown]
# # Nishant Rai

# %%
1. What are escape characters, and how do you use them?

Answer: -
    
    
Escape characters stand for ceratin characters in strings that might be difficult, illegal 
or impossible to use in code.

example: Escape character '\n' represent new line

# %%
2. What do the escape characters n and t stand for?

Answer: -
  
Escape character '\n' stand for new line.
Escape character '\t' stand for a tab.

# %%
3. What is the way to include backslash characters in a string?

Answer: -
    
we can use backslash characters in a string by using double backslash

example:
       '\\n'
       print("We the people \\n of India")

# %%
4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not 
escaped a problem?

Answer:-
    
 Because the entire string is enclosed within a double quote.

# %%
5. How do you write a string of newlines if you 
   don't want to use the n character?
    
Answer: -
    
we can use the triple quotes to write a string of newlines. 

string = """ 
             My name is a Nishant Rai
             
             And i am 
             
             a 
             
             Coder
             
             """

here is a way we can write string of new lines if 
we don't want to use the n characters

# %%
6. What are the values of the given expressions?
'Hello, world!'[1]
Answer:- 'e'
    
    
'Hello, world!'[0:5]
Answer:- 'Hello'


'Hello, world!'[:5]
Answer:- 'Hello'

    
'Hello, world!'[3:]
Answer:-'lo, world!'

# %%
7. What are the values of the following expressions?
'Hello'.upper()
Answer:- 'HELLO'


'Hello'.upper().isupper()
Answer:- True
    
'Hello'.upper().lower()
Answer:-'hello'

# %%
8. What are the values of the following expressions?
'Remember, remember, the fifth of July.'.split()

Answer:- ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
    
'-'.join('There can only one.'.split())
Answer:- 'There-can-only-one.'

# %%
9. What are the methods for right-justifying, left-justifying, 
   and centering a string?

Answer:- 
    
 rjust(), ljust(), center()

# %%
10. What is the best way to remove whitespace characters 
   from the start or end?
    
Answer:-
    
the best way to remove whitespace characters from the start 
or end is to use the strip() fucntion

one can also use lstrip() or rstrip().

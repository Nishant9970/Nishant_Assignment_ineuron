# %% [markdown]
# # Assignment 4

# %% [markdown]
# Nishant Rai

# %%
1. What exactly is []?

Answer: -
    
the [] is an empty list

# %%
2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the
third value? (Assume [2, 4, 6, 8, 10] are in spam.)

Answer: -
we can use spam.insert(2,'hello')

# %%
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %%
3. What is the value of spam[int(int('3' * 2) / 11)]?

Answer: -
    
the value of spam[int(int('3' * 2) / 11)] will be 'd'   

int('3' *2) will evaluate to 33

then int(33/11) will evaluate to 3

then spam[3] will be 'd'

# %%
4. What is the value of spam[-1]?

Answer: -
the value of spam[-1] is 'd'

# %%
5. What is the value of spam[:2]?

Answer: -

the value of spam[:2] is ['a','b']

# %%
Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
6. What is the value of bacon.index('cat')?

Answer: -
 
the value of bacon.index('cat') is 1

# %%
7. How does bacon.append(99) change the look of the list value in bacon?

Answer: -

bacon.append(99) will add the value 99 to the end of bacon list.

after this operation bacon will look like

[3.14, 'cat', 11, 'cat', True,99]

# %%
8. How does bacon.remove('cat') change the look of the list in bacon?

Answer:-

bacon.remove('cat') will remove the first occurrence of value the 'cat'

# %%
9. What are the list concatenation and list replication operators?

Answer: -

list concatenation operator is +
list replication operator is *

# %%
10. What is difference between the list methods append() and insert()?

Answer: -
 
append() will add the element to the end of the given list

insert() will add the element at the specified index.

# %%
11. What are the two methods for removing items from a list?

Answer: -

del list1[0]
list1.remove('value')

# %%
12. Describe how list values and string values are identical.

Answer: -

We can randomly access values using index in both list and string.

We can use index slicing on both list and string.

We can use the concatenation and replication operators on both list and string.

We can pass both list and string to the len() function of python.

We can use the loops on both list and strings.

We can use in operator on both list and string.

# %%
13. What's the difference between tuples and lists?

Answer: -
    
tuples are immutable 
we cannot use functions like insert, remove etc on tuples (except index()  and count())


lists are mutable
we can use multiple functions on lists such as insert, remove etc

# %%
14. How do you type a tuple value that only contains the integer 42?

Answer: -

A tuple value that contains ony 42 will look like (42,) 

example: -
tuple1 = (42,)

# %%
15. How do you get a list value's tuple form? How do you get a tuple value's list form?

Answer: -
 
we can use the tuple() function  to  get a list value's tuple form.

we can use the list() function to get a tuple value's list form.

# %%
16 .Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

Answer: -
    
Variables that contain list values have a reference to list values.

# %%
17. How do you distinguish between copy.copy() and copy.deepcopy()?

Answer: -
    
copy.copy() will do a shallow copy i.e. it will create a copy of the varible and then insert reference to the original variable
copy.deepcopy() will do a deep copy i.e. it will create entirely a new copy of the variable
